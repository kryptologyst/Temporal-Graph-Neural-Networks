# %%
"""Example notebook for temporal graph neural networks."""

import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# Add src to path
import sys
sys.path.append(str(Path.cwd() / "src"))

from src.models import EvolveGCN, TGAT, TGN, DyRep
from src.data import TemporalGraphDataset, create_temporal_graph_data
from src.train import TemporalTrainer
from src.eval import TemporalEvaluator
from src.utils import set_seed, get_device

# Set random seed for reproducibility
set_seed(42)

print("Temporal Graph Neural Networks Example")
print("=" * 50)
